# %% [markdown]
# # Data Project Pitch

# %% [markdown]
# ### Σύνοψη

# %% [markdown]
# Η ψυχική υγεία είναι ένα ζήτημα που χρήζει ιδιαίτερης προσοχής καθώς επηρεάζει την ζωή μας σε κάθε της έκφανση. Ωστόσο για μεγάλο μέρος του παγκόσμιου πληθυσμού δεν αποτελεί προτεραιότητα, με αποτέλεσμα πολλά άτομα να αμφισβητούν ακόμα και τον λόγο ύπαρξής τους. Δεν είναι λοιπόν λίγες οι περιπτώσεις αυτοκτονιών που ανα τα χρόνια βγαίνουν στη επιφάνεια. Έτσι λοιπόν ,αποφασίσαμε να ασχοληθούμε πρώτον με τα ποσοστά αυτοκτονιών στην Ευρώπη από το 2011 εως το 2019 όσον αφορά το φύλο (γυναίκες - άνδρες) και δεύτερον πως κύμαινονται τα ποσοστά των ίδιων χρονολογιών στις ηλικίες 15-19. Συγκεκριμένα, λόγω του πλήθους δεδομένων που συγκεντρώνονται, καταλήξαμε στην επιλογή 4 χωρών για ανάλυση βασιζόμενες στα ποσοστά πληθυσμού που ήταν παρόμοια (Ελλάδα- 10,423,054, Τσεχία- 10,708,981, Πορτογαλία- 10,196,709, Σουηδία- 10,099,265)

# %% [markdown]
# ### Έμπνευση

# %% [markdown]
# Το podcast του Άρη Δημοκίδη στην lifo https://www.lifo.gr/podcasts/wraia-pragmata/i-skliri-alitheia-gia-ta-aorata-paidia ήταν το έναυσμα για να ασχοληθούμε με ένα ζήτημα ψυχικής υγείας.

# %% [markdown]
# ### Περαιτέρω πληροφορίες για το θέμα σας

# %% [markdown]
# - <b>Τίτλος εργασίας</b>: Μια έρευνα για τα ποσοστά αυτοκτονιών στην Ευρώπη
# - <b>Δεδομένα</b>: https://ec.europa.eu/eurostat/databrowser/view/tps00122/default/table?lang=en , https://ec.europa.eu/eurostat/databrowser/view/tps00202/default/table?lang=en
#  ΄Αλλες πηγές δεδομένων : https://uk.style.yahoo.com/male-suicide-mental-health-114400250.html , https://www.worldometers.info/population/countries-in-europe-by-population/, https://www.who.int/news-room/fact-sheets/detail/suicide?fbclid=IwAR1hLjfRjwIMJqNUZEVsScyj5Mkm5EcA6HBohNe25N3kC2qRzqF3lXztI6E, http://suicide-help.gr/alithies-ke-mythi-gia-tin-aftoktonia-synentefxi-sti-lifo/, https://www.in.gr/2022/12/19/greece/palaio-faliro-oi-teleytaies-lekseis-tou-16xronou-prin-valei-telos-sti-zoi-tou/, https://www.athensmagazine.gr/article/news/281519-ebalan-telos-sth-zwh-toys-oi-tragikes-istories-15-diashmwn-poy-aytoktonhsan-photo

# %% [markdown]
# ## Ερευνητικά ερωτήματα

# %% [markdown]
# 1. Ποια είναι τα ποσοστά αυτοκτονίας από το 2011-2019;
# 2. Σε ποιο φύλο παρατηρούνται υψηλότερα ποσοστά αυτοκτονιών στις 4 χώρες(Ελλάδα, Σουηδία, Πορτογαλία, Τσεχία) που θα οπτικοποιηθούν;
# 3. Σε ποια χώρα και σε ποια χρονολογία παρουσιάζεται το μεγαλύτερο ποσοστό;
# 4. Πως κυμαίνονται τα ποσοστά αυτοκτονιών στις ηλικίες 15-19;
# 5. Πως διαφέρουν τα ποσοστά των ηλικιών 15-19 στις 4 χώρες (Ελλάδα, Σουηδία, Πορτογαλία, Τσεχία) που θα οπτικοποιηθούν;

# %% [markdown]
# ## Προέρευνα/δουλειά που έχετε ήδη κάνει στο πλαίσιο του σχεδιασμού του πρότζεκτ

# %% [markdown]
# - <i> Σύμφωνα με αυτό το πρότυπο θα οπτικοποιήσουμε τα δεδομένα μας : [319711457_462057912754399_6761762613834243853_n.jpg](attachment:319711457_462057912754399_6761762613834243853_n.jpg)

# %% [markdown]
# ## Απαντήστε "YES" ή "NO" στα παρακάτω ερωτήματα
# <i>(Στο στάδιο της πρότασης θέματος που βρίσκεστε, το αναμενόμενο είναι YES. Όσα περισσότερα NO, τόσο λιγότερο έχετε προετοιμαστεί και, άρα, χρειάζεται να σχεδιάσετε καλύτερα το πρότζεκτ σας.)</i>

# %%
input("Έχετε ψάξει για πηγές δεδομένων για το θέμα που θέλετε να κάνετε;")
"ΥΕS"

# %%
input("Έχετε βρει δεδομένα/πηγές δεδομένων για το θέμα που θέλετε να κάνετε;")
"YES"

# %%
input("Έχετε περάσει χρόνο εξερευνώντας τα δεδομένα σας; Έχετε καταλάβει τι έχετε, σε ποια μορφή είναι και ενδεχομένως τι σας λείπει;")
"YES"

# %%
input("Έχετε διατυπώσει τα ερευνητικά ερωτήματά σας;")
"YES"

# %%
input("Έχετε σκεφτεί πώς θα αναλύσετε τα δεδομένα σας, για να απαντήσετε τα ερευνητικά ερωτήματά σας;")
"YES"

# %%
input("Έχετε αρχίσει να σκέφτεστε πώς θα μπορούσατε να οπτικοποιήσετε τις αναλύσεις σας για το τελικό σας story;")
"YES"

# %%
input("Έχετε καταθέσει το pitch σας (το προτεινόμενο θέμα σας) σε ένα notebook με filename PITCH_ΟΝΟΜΑΤΕΠΩΝΥΜΟ1_ΟΝΟΜΑΤΕΠΩΝΥΜΟ2;")
"YES"

# %% [markdown]
# ### Feedback!
#
# Το θέμα που έχετε προτείνει είναι, γενικά δημοσιογραφικά, φυσικά πολύ ενδιαφέρον.
# Ωστόσο, στις πηγές δεδομένων σας, δεν βλέπω να έχετε παραθέσει datasets ή/και σελίδες από τις οποίες μπορείτε να συλλέξετε δεδομένα (scraping). Το κείμενο της Ευρωπαϊκής Ένωσης όπως και η αρθρογραφία που έχετε παραθέσει δεν είναι πηγές δεδομένων. Ακόμη και αν κάποιο από αυτά, περιέχει κάποια στοιχεία, αυτά δεν είναι πρωτογενή δεδομένα, αλλά προεπεξεργασμένα στοιχεία (ήδη επεξεργασμένα από κάποιους και τα άρθρα τα επικαλούνται). Δεδομένου ότι δικός μας στόχος είναι η πρωτογενής έρευνα και ανάλυση δεδομένων, και όχι η αναπαραγωγή στατιστικών στοιχείων, θα πρότεινα:
# α) Δείτε αν μπορείτε να εξειδικεύσετε την έρευνά σας, εστιάζοντας σε ένα από τα ερευνητικά ερωτήματα και, βέβαια,
# β) Δείτε αν υπάρχουν δεδομένα/πηγές δεδομένων (μετρήσιμων) για το θέμα σας. πχ Υπάρχουν στοιχεία για το πλήθος των ανθρώπων που συμμετείχε ανά διαδήλωση;
# γ) Σκεφτείτε εάν χρειάζεται να αλλάξετε θέμα, στρεφόμενες σε κάτι που όχι μόνο σας ενδιαφέρει αλλά επίσης μπορείτε να βρείτε δεδομένα για να τα αναλύσετε και να τα οπτικοποιήσετε σε γραφήματα.
# Εκτός από ακόμη μία ομάδα, που επίσης προσανατολίζεται σε αλλαγή θέματος, οι υπόλοιπες ομάδες έχουν προτείνει θέματα που είναι στην κατεύθυνση του data journalism. Επομένως, μπορείτε να ρίξετε και μια ματιά στα pitches των συμφοιτητών/τριών σας για περισσότερη έμπνευση.

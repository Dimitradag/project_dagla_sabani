# %% [markdown]
# JUPYTER NOTEBOOK : males_females
#
# Αρχικά ανοίγουμε την βιβλιοθήκη των pandas και την καλούμε ως pd.
# Αφού έχουμε αποθηκεύσει τα datasets  ως csv τα ανοίγουμε στα pandas.
# Ανοίγουμε και εμφανίζουμε ολόκληρο των πινάκα με τα ποσοστά αυτοκτονιών στους άνδρες στις χρονολογίες 2011-2019.
# Variable -> df = ολόκληρος ο αρχικός πίνακας.
# Στην συνέχεια σβήνουμε τις στήλες που είναι περιττές για την έρευνά μας και ξανα εμφανίζουμε τον πίνακα εκ νέου.
# Προχωράμε στην διαγραφή των κενών που περιέχει ο πίνακας και την στήλη που δεν περιέχει χρήσιμα δεδομένα προς ανάλυση.
# Χρησιμοποιούμε ένα καινούργιο variable (df1) ώστε να μετονομάσουμε τους τιτλους των στηλών και να εμφανιστούν σε έναν νέο πίνακα , τον df1.
# Ύστερα ανοίγουμε ξανά στα pandas το csv με τα ποσοστά των γυναικών, εμφανίζοντάς τα δεδομένα σε έναν πίνακα που τον ονομάσαμε df2 (variable -> df2).
# Διαγράφουμε τα περιττά δεδομένα και τις κενές τιμές.
# Με νέο variable -> df3 εμφανίζουμε έναν πίνακα χωρίς την στήλη NaN.
# Μετονομάζουμε τους τίτλους των στηλών από το df3.
# Ονομάζουμε το df1 -> sex_table και ενώνουμε τους δύο πίνακες που έχουν προκύψει (άνδρες , γυναίκες).
# Ομαδοποιούμε τα δεδομένα βγάζοντας τον μέσο όρο των ποσοστών ανδρών και γυναικών.
# Ανοίγουμε το matplotlib και το καλούμε ως plt.
# Κατεβάζουμε το csv με όνομα sex_table για να δούμε πως έχουν διαμορφωθεί τα δεδομένα.
# Ανοίγουμε το csv sex_table ορίζοντάς το ως df.
# Δημιουργούμε ένα καινουίργιο varible -> df1 που εμφανίζει εναλλάξ τα ποσοστά ανρών και γυναικών αν χώρα και χρονολογία.
# Για την οπτικοποίηση των χωρών (Ελλάδα, Τσεχία, Πορτογαλία, Σουηδία) , χρησιμοποιούμε χρονογραμμές.Συγκεκριμένα δημιουργούμε ένα plot για την κάθε χώρα  όπου με διαφορετικό χρώμα η κάθε γραμμή  εμφανίζει την πορεία των θανάτων του κάθε φύλου.
# Τέλος , με εντολή που διατρέχει όλες τις γραμμές εμφανίζουμε το μεγαλύτερο ποσοστό που υπάρχει στο df1.
#
# JUPYTER NOTEBOOK : 15_19
#
# Ανοίγουμε την βιβλιοθήκη των pandas και την καλούμε ως pd.
# Αφού έχουμε αποθηκεύσει τo dataset  ως csv τo ανοίγουμε στα pandas.
# Ανοίγουμε και εμφανίζουμε ολόκληρο των πίνακα με τα ποσοστά για το ηλικιακό φάσμα 15-19 στις χρονολογίες 2011-2019 σε ένα variable που ονομάζεται df.
# Στην συνέχεια διαγράφουμε τα δεδομένα που δεν είναι χρήσιμα για την έρευνά μας.
# Σβήνουμε τις κενές τιμές και την τελευταία στήλη και εμφανίζουμε τον νέο πίνακα σε ένα καινούργιο variable -> df1.
# Μετονομάζουμε τους τίτλους των στηλών.
# Για την οπτικοποίηση των 4 χωρών χρησιμοποιούμε ραβδογράμματα (barchart). Σε κάθε χώρα επιλέγουμε διαφορετικό χρώμα για την απεικόνιση της πορείας των θανάτων ανα τα χρόνια στο συγκεκριμένο ηλικικό φάσμα.
# Τέλος, με εντολή που διατρέχει όλες τις γραμμές εμφανίζουμε το μεγαλύτερο ποσοστό που υπάρχει στο df1.
#
# Και για τα δύο jupyter notebook μας ισχύουν οι εξής συντομογραφίες:
# AT = AUSTRIA, BE= BELGIUM, BG= BULGARIA, CH = SWITZERLAND, CY = CYPRUS, CZ = CZECHIA, DE = GERMANY, DE = DENMARK, EE = ESTONIA, EL = GREECE, ES = SPAIN, FI = FINLAND, FR = FRANCE, HR = CROATIA, HU = HUNGARY, IE = IRELAND, IS = ICELAND, IT = ITALY, LI = LIECHTENSTEIN, LT = LITHUANIA, LU = LUXEMBOURG, LV = POLAND, MT = MALTA, NL = NETHERLANDS, NO = NORWAY, PL = POLAND, PT = PORTUGAL, RO = ROMANIA, PS = SERBIA, SE = SWEDEN, SI = SLOVENIA, SK = SLOVAKIA, TR = TURKIYE, UK = UNITED KINGDOM
# Επίσης, παρουσιάζονται υποκαταγραφές στις χώρες:
# Γαλλία το 2018 και το 2019 και στα δύο φύλα και στις ηλικίες 15-19.
# Ηνωμένο Βασίλειο το 2019 και στα δύο φύλα και στις ηλικίες 15-19.
# Αλβανία, Βόρεια Μακεδονία, Μαυροβούνιο δεν υπάρχει καμία καταγραφή.
# Μάλτα το 2011 μόνο στις γυναίκες και το 2012, 2018 και 2019 στις ηλικίες 15-19.
# Λιχτενστάιν το 2013, 2014, 2015 στις γυναίκες και το 2011, 2013, 2014, 2015, 2016, 2017, 2018, 2019 στις ηλικίες 15-19.
# Ισλανδία το 2012 στις ηλικίες 15-19.

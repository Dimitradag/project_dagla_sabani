# %%
import pandas as pd

# %%
df=pd.read_csv("tps00202_page_linear.csv")

# %%
df.columns=df.iloc[0]

# %%
df
# Out:
# 0    ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19  \
# 0    ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# 1    ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# 2    ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# 3    ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# 4    ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# ..                   ...                ... ..  ..           ... ..     ...
# 312  ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# 313  ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# 314  ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# 315  ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
# 316  ESTAT:TPS00202(1.0)  09/12/22 23:00:00  A  RT  X60-X84_Y870  T  Y15-19
#
# 0    AT  2011   6.1  NaN
# 0    AT  2011  6.10  NaN
# ...

# %%
df.drop(["ESTAT:TPS00202(1.0)", "09/12/22 23:00:00", "A", "RT", "X60-X84_Y870"], axis = 1, inplace = True)

# %%
df
# Out:
# 0    T  Y15-19  AT  2011   6.1  NaN
# 0    T  Y15-19  AT  2011  6.10  NaN
# 1    T  Y15-19  AT  2012  4.33  NaN
# 2    T  Y15-19  AT  2013  6.10  NaN
# 3    T  Y15-19  AT  2014  9.02  NaN
# 4    T  Y15-19  AT  2015  6.71  NaN
# ..  ..     ...  ..   ...   ...  ...
# 312  T  Y15-19  UK  2014  3.19  NaN
# 313  T  Y15-19  UK  2015  3.90  NaN
# 314  T  Y15-19  UK  2016  4.27  NaN
# 315  T  Y15-19  UK  2017  4.69  NaN
# 316  T  Y15-19  UK  2018  5.26    p
#
# [317 rows x 6 columns]

# %%
df1= df.drop(df.columns[[-1]],axis = 1)

# %%
df1
# Out:
# 0    T  Y15-19  AT  2011   6.1
# 0    T  Y15-19  AT  2011  6.10
# 1    T  Y15-19  AT  2012  4.33
# 2    T  Y15-19  AT  2013  6.10
# 3    T  Y15-19  AT  2014  9.02
# 4    T  Y15-19  AT  2015  6.71
# ..  ..     ...  ..   ...   ...
# 312  T  Y15-19  UK  2014  3.19
# 313  T  Y15-19  UK  2015  3.90
# 314  T  Y15-19  UK  2016  4.27
# 315  T  Y15-19  UK  2017  4.69
# 316  T  Y15-19  UK  2018  5.26
#
# [317 rows x 5 columns]

# %%
df1.columns= ["SEX", "AGE", "COUNTRY", "TIME_PERIOD", "PERCENTAGE"]

# %%
df1
# Out:
#     SEX     AGE COUNTRY  TIME_PERIOD  PERCENTAGE
# 0     T  Y15-19      AT         2011        6.10
# 1     T  Y15-19      AT         2012        4.33
# 2     T  Y15-19      AT         2013        6.10
# 3     T  Y15-19      AT         2014        9.02
# 4     T  Y15-19      AT         2015        6.71
# ..   ..     ...     ...          ...         ...
# 312   T  Y15-19      UK         2014        3.19
# 313   T  Y15-19      UK         2015        3.90
# 314   T  Y15-19      UK         2016        4.27
# 315   T  Y15-19      UK         2017        4.69
# 316   T  Y15-19      UK         2018        5.26
#
# [317 rows x 5 columns]

# %%
ax = df1[(df1.COUNTRY=='EL')].plot(kind='bar',x='TIME_PERIOD',y='PERCENTAGE',color='blue')

df1[(df1.COUNTRY=='EL')].plot(kind='bar',x='TIME_PERIOD',y='PERCENTAGE',color='blue',ax=ax)
# Out:
# <AxesSubplot: xlabel='TIME_PERIOD'>

# %%
ax = df1[(df1.COUNTRY=='PT')].plot(kind='bar',x='TIME_PERIOD',y='PERCENTAGE',color='green')

df1[(df1.COUNTRY=='PT')].plot(kind='bar',x='TIME_PERIOD',y='PERCENTAGE',color='green',ax=ax)
# Out:
# <AxesSubplot: xlabel='TIME_PERIOD'>

# %%
ax = df1[(df1.COUNTRY=='SE')].plot(kind='bar',x='TIME_PERIOD',y='PERCENTAGE',color='yellow')

df1[(df1.COUNTRY=='SE')].plot(kind='bar',x='TIME_PERIOD',y='PERCENTAGE',color='yellow',ax=ax)
# Out:
# <AxesSubplot: xlabel='TIME_PERIOD'>

# %%
ax = df1[(df1.COUNTRY=='CZ')].plot(kind='bar',x='TIME_PERIOD',y='PERCENTAGE',color='red')

df1[(df1.COUNTRY=='CZ')].plot(kind='bar',x='TIME_PERIOD',y='PERCENTAGE',color='red',ax=ax)
# Out:
# <AxesSubplot: xlabel='TIME_PERIOD'>

# %%
maxValues = df1.max()
print(maxValues)
# Out:
# SEX                 T
# AGE            Y15-19
# COUNTRY            UK
# TIME_PERIOD      2019
# PERCENTAGE      22.79
# dtype: object

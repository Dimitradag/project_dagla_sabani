# %%
#import pandas and call it pd from this moment onwards in this notebook
import pandas as pd

# %%
#Read csv using pandas
df = pd.read_csv("tps00122_page_linear (3).csv")

# %%
#df with all columns label and all rows of csv
df.columns=df.iloc[0]

# %%
#print out this dataframe
df
# Out:
# 0    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M  \
# 0    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# 1    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# 2    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# 3    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# 4    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# ..                   ...                ... ..  ..    ...           ... ..
# 312  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# 313  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# 314  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# 315  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
# 316  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  M
#
# 0    AT  2011  26.13  NaN
# 0    AT  2011  26.13  NaN
# ...

# %%
#dropping passed columns
df.drop(["ESTAT:TPS00122(1.0)", "09/12/22 23:00:00", "A", "RT", "X60-X84_Y870"], axis = 1, inplace = True)

# %%
df
# Out:
# 0    TOTAL  M  AT  2011  26.13  NaN
# 0    TOTAL  M  AT  2011  26.13  NaN
# 1    TOTAL  M  AT  2012  25.84  NaN
# 2    TOTAL  M  AT  2013  25.60  NaN
# 3    TOTAL  M  AT  2014  25.29  NaN
# 4    TOTAL  M  AT  2015  24.19  NaN
# ..     ... ..  ..   ...    ...  ...
# 312  TOTAL  M  UK  2014  11.24  NaN
# 313  TOTAL  M  UK  2015  11.53  NaN
# 314  TOTAL  M  UK  2016  11.31  NaN
# 315  TOTAL  M  UK  2017  11.79  NaN
# 316  TOTAL  M  UK  2018  12.91    p
#
# [317 rows x 6 columns]

# %%
#drop any rows containing missing values in any variable
df.dropna()
# Out:
# 0    TOTAL  M  AT  2011  26.13 NaN
# 7    TOTAL  M  AT  2018  23.49   p
# 8    TOTAL  M  AT  2019  20.88   p
# 16   TOTAL  M  BE  2018  23.83   p
# 17   TOTAL  M  BE  2019  23.16   p
# 25   TOTAL  M  BG  2018  15.13   p
# ..     ... ..  ..   ...    ...  ..
# 306  TOTAL  M  TR  2017   6.06   d
# 307  TOTAL  M  TR  2018   7.18  dp
# 308  TOTAL  M  TR  2019   7.02  dp
# 309  TOTAL  M  UK  2011  10.84   d
# 316  TOTAL  M  UK  2018  12.91   p
#
# [81 rows x 6 columns]

# %%
#in df1 delete column with labels on given axis or missing values
df1=df.dropna(axis=1)

# %%
#print out this dataframe
df1
# Out:
# 0    TOTAL  M  AT  2011  26.13
# 0    TOTAL  M  AT  2011  26.13
# 1    TOTAL  M  AT  2012  25.84
# 2    TOTAL  M  AT  2013  25.60
# 3    TOTAL  M  AT  2014  25.29
# 4    TOTAL  M  AT  2015  24.19
# ..     ... ..  ..   ...    ...
# 312  TOTAL  M  UK  2014  11.24
# 313  TOTAL  M  UK  2015  11.53
# 314  TOTAL  M  UK  2016  11.31
# 315  TOTAL  M  UK  2017  11.79
# 316  TOTAL  M  UK  2018  12.91
#
# [317 rows x 5 columns]

# %%
#rename column's titles
df1.columns = ["AGE", "SEX", "COUNTRY", "TIME_PERIOD","PERCENTAGE"]

# %%
df1
# Out:
#        AGE SEX COUNTRY  TIME_PERIOD  PERCENTAGE
# 0    TOTAL   M      AT         2011       26.13
# 1    TOTAL   M      AT         2012       25.84
# 2    TOTAL   M      AT         2013       25.60
# 3    TOTAL   M      AT         2014       25.29
# 4    TOTAL   M      AT         2015       24.19
# ..     ...  ..     ...          ...         ...
# 312  TOTAL   M      UK         2014       11.24
# 313  TOTAL   M      UK         2015       11.53
# 314  TOTAL   M      UK         2016       11.31
# 315  TOTAL   M      UK         2017       11.79
# 316  TOTAL   M      UK         2018       12.91
#
# [317 rows x 5 columns]

# %%
#Read csv using pandas
df2 = pd.read_csv("tps00122_page_linear (4).csv")

# %%
df2.columns=df2.iloc[0]

# %%
df2
# Out:
# 0    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F  \
# 0    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# 1    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# 2    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# 3    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# 4    ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# ..                   ...                ... ..  ..    ...           ... ..
# 308  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# 309  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# 310  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# 311  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
# 312  ESTAT:TPS00122(1.0)  09/12/22 23:00:00  A  RT  TOTAL  X60-X84_Y870  F
#
# 0    AT  2011  7.16  NaN
# 0    AT  2011  7.16  NaN
# ...

# %%
#delete columns we don't need
df2.drop(["ESTAT:TPS00122(1.0)", "09/12/22 23:00:00", "A", "RT", "X60-X84_Y870"], axis = 1, inplace = True)

# %%
df2
# Out:
# 0    TOTAL  F  AT  2011  7.16  NaN
# 0    TOTAL  F  AT  2011  7.16  NaN
# 1    TOTAL  F  AT  2012  6.51  NaN
# 2    TOTAL  F  AT  2013  7.19  NaN
# 3    TOTAL  F  AT  2014  7.02  NaN
# 4    TOTAL  F  AT  2015  6.27  NaN
# ..     ... ..  ..   ...   ...  ...
# 308  TOTAL  F  UK  2014  3.17  NaN
# 309  TOTAL  F  UK  2015  3.41  NaN
# 310  TOTAL  F  UK  2016  3.33  NaN
# 311  TOTAL  F  UK  2017  3.32  NaN
# 312  TOTAL  F  UK  2018  3.81    p
#
# [313 rows x 6 columns]

# %%
#drop any rows containing missing values in any variable
df2.dropna()
# Out:
# 0    TOTAL  F  AT  2011  7.16 NaN
# 7    TOTAL  F  AT  2018  5.51   p
# 8    TOTAL  F  AT  2019  5.16   p
# 16   TOTAL  F  BE  2018  8.77   p
# 17   TOTAL  F  BE  2019  7.92   p
# 25   TOTAL  F  BG  2018  3.80   p
# ..     ... ..  ..   ...   ...  ..
# 302  TOTAL  F  TR  2017  1.56   d
# 303  TOTAL  F  TR  2018  2.06  dp
# 304  TOTAL  F  TR  2019  1.92  dp
# 305  TOTAL  F  UK  2011  2.80   d
# 312  TOTAL  F  UK  2018  3.81   p
#
# [81 rows x 6 columns]

# %%
#in df3 delete column with labels on given axis or missing values
df3=df2.dropna(axis=1)

# %%
df3
# Out:
# 0    TOTAL  F  AT  2011  7.16
# 0    TOTAL  F  AT  2011  7.16
# 1    TOTAL  F  AT  2012  6.51
# 2    TOTAL  F  AT  2013  7.19
# 3    TOTAL  F  AT  2014  7.02
# 4    TOTAL  F  AT  2015  6.27
# ..     ... ..  ..   ...   ...
# 308  TOTAL  F  UK  2014  3.17
# 309  TOTAL  F  UK  2015  3.41
# 310  TOTAL  F  UK  2016  3.33
# 311  TOTAL  F  UK  2017  3.32
# 312  TOTAL  F  UK  2018  3.81
#
# [313 rows x 5 columns]

# %%
#rename column's titles
df3.columns = ["AGE", "SEX", "COUNTRY", "TIME_PERIOD","PERCENTAGE"]

# %%
df3
# Out:
#        AGE SEX COUNTRY  TIME_PERIOD  PERCENTAGE
# 0    TOTAL   F      AT         2011        7.16
# 1    TOTAL   F      AT         2012        6.51
# 2    TOTAL   F      AT         2013        7.19
# 3    TOTAL   F      AT         2014        7.02
# 4    TOTAL   F      AT         2015        6.27
# ..     ...  ..     ...          ...         ...
# 308  TOTAL   F      UK         2014        3.17
# 309  TOTAL   F      UK         2015        3.41
# 310  TOTAL   F      UK         2016        3.33
# 311  TOTAL   F      UK         2017        3.32
# 312  TOTAL   F      UK         2018        3.81
#
# [313 rows x 5 columns]

# %%
#in variable sex_table conect df1 and df3 in one table
sex_table = pd.concat([df1,df3], axis=0)

# %%
#print out this dataframe
sex_table
# Out:
#        AGE SEX COUNTRY  TIME_PERIOD  PERCENTAGE
# 0    TOTAL   M      AT         2011       26.13
# 1    TOTAL   M      AT         2012       25.84
# 2    TOTAL   M      AT         2013       25.60
# 3    TOTAL   M      AT         2014       25.29
# 4    TOTAL   M      AT         2015       24.19
# ..     ...  ..     ...          ...         ...
# 308  TOTAL   F      UK         2014        3.17
# 309  TOTAL   F      UK         2015        3.41
# 310  TOTAL   F      UK         2016        3.33
# 311  TOTAL   F      UK         2017        3.32
# 312  TOTAL   F      UK         2018        3.81
#
# [630 rows x 5 columns]

# %%
#grouped by a list of things: COUNTRY, TIME_PERIOD, calculating the median PERCENTAGE 
sex_table.groupby(["COUNTRY", "TIME_PERIOD"]).sum()
# Out:
# C:\Users\Δήμητρα\AppData\Local\Temp\ipykernel_25364\256509800.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sex_table.groupby(["COUNTRY", "TIME_PERIOD"]).sum()
#                      PERCENTAGE
# COUNTRY TIME_PERIOD
# AT      2011              33.29
#         2012              32.35
#         2013              32.79
#         2014              32.31
#         2015              30.46
# ...                         ...
# UK      2014              14.41
#         2015              14.94
#         2016              14.64
#         2017              15.11
#         2018              16.72
#
# [317 rows x 1 columns]

# %%
#import pandas and call it pd from this moment onwards in this notebook
import pandas as pd 
#import matplotlib and call it plt from this moment onwards in this notebook
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#download sex_table as excel in our pc
sex_table.to_csv('sex_table.csv',index=False)

# %%
#read your csv
df = pd.read_csv('sex_table.csv')

#create a new df, called df1
#this will be your initial df, grouped by a list of things: COUNTRY, TIME_PERIOD, SEX, calculating the median PERCENTAGE. This is just a trick: you are not calculating any median, since there is only one percentage per sex in a country in a given time period. You are just using median() in order to get the real value of the percentage in each grouped case. 
df1 = pd.DataFrame(df.groupby(['COUNTRY','TIME_PERIOD','SEX']).PERCENTAGE.median()).reset_index()

# %%
df1
# Out:
#     COUNTRY  TIME_PERIOD SEX  PERCENTAGE
# 0        AT         2011   F        7.16
# 1        AT         2011   M       26.13
# 2        AT         2012   F        6.51
# 3        AT         2012   M       25.84
# 4        AT         2013   F        7.19
# ..      ...          ...  ..         ...
# 625      UK         2016   M       11.31
# 626      UK         2017   F        3.32
# 627      UK         2017   M       11.79
# 628      UK         2018   F        3.81
# 629      UK         2018   M       12.91
#
# [630 rows x 4 columns]

# %%
#create plot for one country and one sex
ax = df1[(df1.COUNTRY=='EL')&(df1.SEX=='M')].plot(kind='line',x='TIME_PERIOD',y= 'PERCENTAGE' ,color='blue')
#then, overlay with another plot for the other sex and the same country
df1[(df1.COUNTRY=='EL')&(df1.SEX=='F')].plot(kind='line',x='TIME_PERIOD',y= 'PERCENTAGE' ,color='orange',ax=ax)
plt.title("suicides in Greece")
plt.xlabel("TIME_PERIOD")
plt.ylabel("PERCENTAGE")
plt.legend(["males", "females"])
plt.ylim(1, 30)
# Out:
# (1.0, 30.0)

# %%
#create plot for one country and one sex
ax = df1[(df1.COUNTRY=='CZ')&(df1.SEX=='M')].plot(kind='line',x='TIME_PERIOD',y='PERCENTAGE',color='blue')
#then, overlay with another plot for the other sex and the same country
df1[(df1.COUNTRY=='CZ')&(df1.SEX=='F')].plot(kind='line',x='TIME_PERIOD',y='PERCENTAGE',color='orange',ax=ax)
plt.title("suicides in Czechia")
plt.xlabel("TIME_PERIOD")
plt.ylabel("PERCENTAGE")
plt.legend(["males", "females"])
plt.ylim(1, 30)
# Out:
# (1.0, 30.0)

# %%
#create plot for one country and one sex
ax = df1[(df1.COUNTRY=='PT')&(df1.SEX=='M')].plot(kind='line',x='TIME_PERIOD',y='PERCENTAGE',color='blue')
#then, overlay with another plot for the other sex and the same country
df1[(df1.COUNTRY=='PT')&(df1.SEX=='F')].plot(kind='line',x='TIME_PERIOD',y='PERCENTAGE',color='orange',ax=ax)
plt.title("suicides in Portugal")
plt.xlabel("TIME_PERIOD")
plt.ylabel("PERCENTAGE")
plt.legend(["males", "females"])
plt.ylim(1, 30)
# Out:
# (1.0, 30.0)

# %%
#create plot for one country and one sex
ax = df1[(df1.COUNTRY=='SE')&(df1.SEX=='M')].plot(kind='line',x='TIME_PERIOD',y='PERCENTAGE',color='blue')
#then, overlay with another plot for the other sex and the same country
df1[(df1.COUNTRY=='SE')&(df1.SEX=='F')].plot(kind='line',x='TIME_PERIOD',y='PERCENTAGE',color='orange',ax=ax)
plt.title("suicides in Sweden")
plt.xlabel("TIME_PERIOD")
plt.ylabel("PERCENTAGE")
plt.legend(["males", "females"])
plt.ylim(1, 30)
# Out:
# (1.0, 30.0)
